# %%
#!pip install gensim
import numpy, pickle, gensim

# %% [markdown]
# Load array of tokenized and cleared texts:

# %%
texts_final = pickle.load(open("texts_final_400w.p", "rb"))

# %% [markdown]
# Create dictionary and corpus:

# %%
dictionary = gensim.corpora.Dictionary(texts_final)
corpus = [dictionary.doc2bow(text) for text in texts_final]

# %% [markdown]
# I used a reduced version of the corpus since jupyter notebook kept crashing:

# %%
corpus_red = [corpus[i] for i in range(0,len(corpus),5)] #reduced corpus using every fifth text

# %% [markdown]
# To load the existing topic models:

# %%
tm59 = gensim.models.LdaModel.load('tm59_reduced')

# %%
tm29 = gensim.models.LdaModel.load('tm29')

# %% [markdown]
# Or create a new topic model with your choice of parameters:

# %%
tm = gensim.models.LdaModel(corpus, id2word=dictionary, num_topics=n, passes=i)

# %% [markdown]
# Visualize the topic model:

# %%
import pyLDAvis.gensim as gensimvis
import pyLDAvis

# %%
lda_display = gensimvis.prepare(tm29, corpus_red, dictionary, sort_topics=False)
pyLDAvis.enable_notebook(local=True)
pyLDAvis.display(lda_display)
# Out:
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/julia/opt/anaconda3/lib/python3.8/site-packages/IPython/html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el10291403217692318565253481899"></div>
# <script type="text/javascript">
#
# ...
